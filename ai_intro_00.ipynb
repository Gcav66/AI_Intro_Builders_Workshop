# %% [markdown]
# <a href="https://colab.research.google.com/github/Gcav66/AI_Intro_Builders_Workshop/blob/main/ai_intro_00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# "Vibe code" a web application to analyze the Forsyth County 2026 Budget

# %% [markdown]
# https://forsyth.cc/budget/assets/documents/FY2026_Preliminary_Budget.pdf
